# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', 500)

# %%
def asf_project(pr):
    name = pr.split("-")[0]
    if name == "incubator":
        return pr.split("-")[1]
    return name

# %%
project = "ozone"

# %%
actions = pd.read_csv("github-action-run.csv.gz")
                          
actions.createdat = pd.to_datetime(actions.createdat * 1000000, utc = True)
actions.updatedat = pd.to_datetime(actions.updatedat * 1000000, utc = True)
actions.firstjobstarted = pd.to_datetime(actions.firstjobstarted * 1000000, utc = True)
actions.lastjobcompleted = pd.to_datetime(actions.lastjobcompleted * 1000000, utc = True)

# %%
actions["project"] = actions.repo.apply(asf_project)
actions["jobhours"] = actions.jobseconds / 60 / 60
actions["month"] = actions.createdat.dt.strftime("%Y-%m")

# %%
actions =  actions[actions.month.isin(["2021-03","2021-02"])]
last_month = "2021-03"
actions = actions[actions.project == project]

# %% [markdown]
# ## Number of jobhours used by month
#
# Maximum available value is 180 * 24 * days == 129600 (30 days) .. 133920 (31 days)

# %%
actions[["jobhours"]].groupby([actions.project,actions.month]).count().reset_index().groupby("month").sum()
# Out:
#          jobhours
# month
# 2021-02       982
# 2021-03      1235

# %% [markdown]
# ## Number of jobs executed by git repositories (last month)

# %%
actions[actions.month == last_month][["repo","jobhours"]].groupby("repo").agg({"jobhours":["sum","mean", "max"]}).sort_values(('jobhours',"sum"), ascending=False).head(20)
# Out:
#                           jobhours
#                                sum      mean        max
# repo
# ozone                  5480.000000  4.488124  17.473333
# ozone-docker-runner       2.500556  0.312569   0.346944
# ozone-docker-builder      1.935556  0.645185   0.654722
# ozone-site                0.004444  0.002222   0.002500
# ozone-docker-testkrb5     0.004167  0.004167   0.004167

# %% [markdown]
# ## Job hour statustics per workflows

# %%
actions[actions.month == last_month][["repo","workflowid","jobhours"]].groupby(["repo","workflowid"]).agg({"jobhours":["sum","mean", "max"]}).sort_values(('jobhours',"sum"), ascending=False)
# Out:
#                                      jobhours
#                                           sum      mean        max
# repo                  workflowid
# ozone                 8247        5479.244444  7.315413  17.473333
# ozone-docker-runner   5665410        2.500556  0.312569   0.346944
# ozone-docker-builder  6309753        1.935556  0.645185   0.654722
# ozone                 582975         0.703611  0.001595   0.003889
#                       2340159        0.051944  0.001676   0.002500
# ozone-site            3241092        0.004444  0.002222   0.002500
# ozone-docker-testkrb5 6903290        0.004167  0.004167   0.004167

# %% [markdown]
# ## Slowest workflow runs

# %%
actions.sort_values("jobhours", ascending=False).head(25)
# Out:
#            org   repo         id  runnumber                 createdat  \
# 776519  apache  ozone  631082566       6396 2021-03-08 04:07:44+00:00
# 775905  apache  ozone  551682230       5843 2021-02-09 14:55:32+00:00
# 775781  apache  ozone  536396483       5731 2021-02-04 07:31:49+00:00
# 776376  apache  ozone  613328110       6267 2021-03-02 08:11:25+00:00
# 776419  apache  ozone  616706424       6305 2021-03-03 07:02:21+00:00
# 776334  apache  ozone  609910560       6229 2021-03-01 08:51:21+00:00
# 776397  apache  ozone  614484905       6286 2021-03-02 15:15:10+00:00
# 776434  apache  ozone  617965540       6319 2021-03-03 15:13:24+00:00
# 776321  apache  ozone  609142520       6217 2021-03-01 02:50:20+00:00
# 776384  apache  ozone  613921074       6274 2021-03-02 11:52:29+00:00
# 776343  apache  ozone  610919385       6237 2021-03-01 15:16:08+00:00
# 776663  apache  ozone  640568746       6525 2021-03-10 20:26:03+00:00
# 776621  apache  ozone  638305083       6488 2021-03-10 06:07:59+00:00
# 776622  apache  ozone  638310529       6489 2021-03-10 06:10:23+00:00
# 776364  apache  ozone  612892851       6256 2021-03-02 04:52:21+00:00
# 776177  apache  ozone  591493817       6088 2021-02-23 05:11:14+00:00
# 776425  apache  ozone  617400807       6310 2021-03-03 11:40:13+00:00
# 776170  apache  ozone  589696288       6081 2021-02-22 15:57:31+00:00
# 776214  apache  ozone  595385565       6120 2021-02-24 08:22:07+00:00
# 776196  apache  ozone  592639221       6104 2021-02-23 13:11:43+00:00
# 776167  apache  ozone  589465368       6079 2021-02-22 14:33:35+00:00
# 777142  apache  ozone  706193245       6957 2021-03-31 19:55:33+00:00
# 776891  apache  ozone  667628710       6730 2021-03-19 10:34:52+00:00
# 777107  apache  ozone  701465978       6925 2021-03-30 12:53:54+00:00
# 776937  apache  ozone  678914818       6772 2021-03-23 08:29:16+00:00
#
#                        updatedat     status conclusion  workflowid  \
# 776519 2021-03-08 10:21:29+00:00  completed    failure        8247
# 775905 2021-02-09 21:04:30+00:00  completed    failure        8247
# 775781 2021-02-04 12:06:55+00:00  completed    failure        8247
# 776376 2021-03-02 15:41:05+00:00  completed    failure        8247
# 776419 2021-03-03 12:29:09+00:00  completed    failure        8247
# 776334 2021-03-01 14:52:13+00:00  completed    failure        8247
# 776397 2021-03-02 23:42:49+00:00  completed    failure        8247
# 776434 2021-03-03 20:43:50+00:00  completed    failure        8247
# 776321 2021-03-01 08:11:33+00:00  completed    failure        8247
# 776384 2021-03-02 17:27:32+00:00  completed    failure        8247
# 776343 2021-03-01 20:50:12+00:00  completed    failure        8247
# 776663 2021-03-10 23:35:25+00:00  completed    failure        8247
# 776621 2021-03-10 10:00:53+00:00  completed  cancelled        8247
# 776622 2021-03-10 10:01:02+00:00  completed  cancelled        8247
# 776364 2021-03-02 08:23:57+00:00  completed  cancelled        8247
# 776177 2021-02-23 08:41:34+00:00  completed    failure        8247
# 776425 2021-03-03 13:59:35+00:00  completed    failure        8247
# 776170 2021-02-22 19:43:42+00:00  completed    failure        8247
# 776214 2021-02-24 12:28:40+00:00  completed    failure        8247
# 776196 2021-02-23 17:16:30+00:00  completed    failure        8247
# 776167 2021-02-22 18:07:40+00:00  completed    failure        8247
# 777142 2021-03-31 23:37:19+00:00  completed    success        8247
# 776891 2021-03-19 14:25:39+00:00  completed    success        8247
# 777107 2021-03-30 16:45:26+00:00  completed    success        8247
# 776937 2021-03-23 11:45:33+00:00  completed    success        8247
#
#                  firstjobstarted          lastjobcompleted  jobdetails  jobs  \
# 776519 2021-03-08 04:09:20+00:00 2021-03-08 10:21:24+00:00        True    16
# 775905 2021-02-09 14:55:49+00:00 2021-02-09 21:04:25+00:00        True    16
# 775781 2021-02-04 07:32:28+00:00 2021-02-04 12:06:51+00:00        True    16
# 776376 2021-03-02 08:54:46+00:00 2021-03-02 15:41:00+00:00        True    16
# 776419 2021-03-03 07:03:22+00:00 2021-03-03 12:29:04+00:00        True    16
# 776334 2021-03-01 08:51:42+00:00 2021-03-01 14:52:09+00:00        True    16
# 776397 2021-03-02 17:10:59+00:00 2021-03-02 23:42:45+00:00        True    16
# 776434 2021-03-03 15:13:59+00:00 2021-03-03 20:43:47+00:00        True    16
# 776321 2021-03-01 02:50:31+00:00 2021-03-01 08:11:29+00:00        True    16
# 776384 2021-03-02 11:53:46+00:00 2021-03-02 17:27:27+00:00        True    16
# 776343 2021-03-01 15:16:58+00:00 2021-03-01 20:50:07+00:00        True    16
# 776663 2021-03-10 20:26:18+00:00 2021-03-10 23:35:20+00:00        True    16
# 776621 2021-03-10 06:08:14+00:00 2021-03-10 10:00:48+00:00        True    16
# 776622 2021-03-10 06:10:34+00:00 2021-03-10 10:00:58+00:00        True    16
# 776364 2021-03-02 04:52:36+00:00 2021-03-02 08:23:51+00:00        True    16
# 776177 2021-02-23 05:11:24+00:00 2021-02-23 08:41:28+00:00        True    16
# 776425 2021-03-03 11:40:32+00:00 2021-03-03 13:59:29+00:00        True    16
# 776170 2021-02-22 16:09:09+00:00 2021-02-22 19:43:36+00:00        True    16
# 776214 2021-02-24 08:49:11+00:00 2021-02-24 12:28:35+00:00        True    16
# 776196 2021-02-23 13:38:13+00:00 2021-02-23 17:16:25+00:00        True    16
# 776167 2021-02-22 14:36:42+00:00 2021-02-22 18:07:35+00:00        True    16
# 777142 2021-03-31 20:05:31+00:00 2021-03-31 23:37:08+00:00        True    16
# 776891 2021-03-19 11:07:46+00:00 2021-03-19 14:25:21+00:00        True    16
# 777107 2021-03-30 13:31:31+00:00 2021-03-30 16:45:15+00:00        True    16
# 776937 2021-03-23 08:46:58+00:00 2021-03-23 11:45:26+00:00        True    16
#
#         jobseconds project   jobhours    month
# 776519       62904   ozone  17.473333  2021-03
# 775905       61452   ozone  17.070000  2021-02
# 775781       49254   ozone  13.681667  2021-02
# 776376       45203   ozone  12.556389  2021-03
# 776419       45150   ozone  12.541667  2021-03
# 776334       44988   ozone  12.496667  2021-03
# 776397       44893   ozone  12.470278  2021-03
# 776434       44545   ozone  12.373611  2021-03
# 776321       44388   ozone  12.330000  2021-03
# 776384       44225   ozone  12.284722  2021-03
# 776343       44116   ozone  12.254444  2021-03
# 776663       43850   ozone  12.180556  2021-03
# 776621       38055   ozone  10.570833  2021-03
# 776622       37977   ozone  10.549167  2021-03
# 776364       37708   ozone  10.474444  2021-03
# 776177       36569   ozone  10.158056  2021-02
# 776425       36548   ozone  10.152222  2021-03
# 776170       36480   ozone  10.133333  2021-02
# 776214       35972   ozone   9.992222  2021-02
# 776196       35921   ozone   9.978056  2021-02
# 776167       34427   ozone   9.563056  2021-02
# 777142       34115   ozone   9.476389  2021-03
# 776891       33764   ozone   9.378889  2021-03
# 777107       33650   ozone   9.347222  2021-03
# 776937       33336   ozone   9.260000  2021-03

# %%
job = pd.read_csv("github-action-job.csv.gz")                          
job.startedat = pd.to_datetime(job.startedat * 1000000, utc = True)
job.completedat = pd.to_datetime(job.completedat * 1000000, utc = True)
job["project"] = job.repo.apply(asf_project)

# %%
job["jobhours"] = (job.completedat - job.startedat).dt.seconds / 60 / 60

# %%
job = job[job.project == project]

# %% [markdown]
# ## Slowest job executions by job names

# %%
job[["jobhours"]].groupby([job.org,job.repo, job.name]).sum().reset_index().sort_values("jobhours", ascending=False).head(25)
# Out:
#        org                  repo                           name     jobhours
# 26  apache                 ozone            integration (ozone)  2302.487222
# 24  apache                 ozone           integration (client)  1783.876389
# 1   apache                 ozone              acceptance (misc)  1656.158056
# 25  apache                 ozone  integration (filesystem-hdds)  1640.197222
# 2   apache                 ozone            acceptance (secure)  1554.366389
# 3   apache                 ozone          acceptance (unsecure)   973.347500
# 29  apache                 ozone                           unit   821.483056
# 27  apache                 ozone                     kubernetes   301.807500
# 22  apache                 ozone                       findbugs   292.545833
# 19  apache                 ozone                   compile (11)   291.781667
# 20  apache                 ozone                    compile (8)   281.530833
# 21  apache                 ozone                       coverage   149.532222
# 16  apache                 ozone                     checkstyle    51.976389
# 28  apache                 ozone                            rat    46.924444
# 13  apache                 ozone                           bats     3.686667
# 31  apache   ozone-docker-runner               build and deploy     3.598333
# 4   apache                 ozone                         author     2.968611
# 12  apache                 ozone                   basic (unit)     2.961944
# 30  apache  ozone-docker-builder               build and deploy     1.935556
# 15  apache                 ozone                  check-comment     1.600556
# 10  apache                 ozone               basic (findbugs)     1.171944
# 14  apache                 ozone                         cancel     0.167500
# 8   apache                 ozone             basic (checkstyle)     0.142778
# 17  apache                 ozone                  close-pending     0.124167
# 11  apache                 ozone                    basic (rat)     0.099722

# %% [markdown]
# ## Number of job executions per status

# %%
job[["id"]].groupby([job.org,job.repo,  job.conclusion]).count().reset_index().sort_values("id", ascending=False).head(25)
# Out:
#       org                   repo conclusion     id
# 3  apache                  ozone    success  23333
# 1  apache                  ozone    failure   1973
# 2  apache                  ozone    skipped   1546
# 0  apache                  ozone  cancelled   1082
# 8  apache               ozone-go    success     38
# 5  apache    ozone-docker-runner    success     12
# 4  apache   ozone-docker-builder    success      3
# 9  apache             ozone-site    success      2
# 6  apache  ozone-docker-testkrb5    success      1
# 7  apache               ozone-go    failure      1

# %%
start = job.loc[:,["org","repo","project","id","runid","startedat"]]
start["value"] = 1
start = start.rename(columns={"startedat":"date"})

end = job.loc[:,["org","repo","project","id","runid","completedat"]]
end["value"] = -1
end = end.rename(columns={"completedat":"date"})
events = pd.concat([start, end]).sort_values("date")
events["running"] = events.value.cumsum()

# %% [markdown]
# ## Average (12h window) parallel running/queued job at a given time

# %%
r = events.set_index('date')
r = r.sort_index()
r = r.resample("12H").mean().fillna(0)

plt.figure(figsize=(20,8))
plt.plot(r.index,r.running)
plt.show()

# %%
## Max (12h window) parallel running/queued job at a given time

# %%
r = events.set_index('date')
r = r.sort_index()
r = r.resample("12H").max().fillna(0)

plt.figure(figsize=(20,8))
plt.plot(r.index,r.running)
plt.show()
